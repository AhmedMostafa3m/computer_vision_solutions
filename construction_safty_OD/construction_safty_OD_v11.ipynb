# %%
! nvidia-smi
# Out:
# Tue Dec 24 20:05:23 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 903.1/903.1 kB 22.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model=yolo11s.pt source="https://ultralytics.com/images/bus.jpg" show=True
# Out:
# ...
# 100% 18.4M/18.4M [00:00<00:00, 210MB/s]
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics 8.3.54 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11s summary (fused): 238 layers, 9,443,760 parameters, 0 gradients, 21.5 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 50.3ms
# Speed: 3.2ms preprocess, 50.3ms inference, 593.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# train yolov11n on our data set
# !yolo task=detect mode=train model=yolo11s.pt data=/content/drive/MyDrive/Datasets/construction_safty_OD_v11/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.54 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/drive/MyDrive/Datasets/construction_safty_OD_v11/data.yaml
# Out:
# Ultralytics 8.3.54 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11s summary (fused): 238 layers, 9,416,283 parameters, 0 gradients, 21.3 GFLOPs
# val: Scanning /content/drive/MyDrive/Datasets/construction_safty_OD_v11/valid/labels.cache... 117 images, 1 backgrounds, 0 corrupt: 100% 117/117 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:04<00:00,  1.96it/s]
#                    all        117        586      0.701      0.542      0.568       0.41
#                  Boots         83        172      0.899      0.924      0.948      0.692
#                Hardhat         91        123      0.896      0.906      0.909      0.659
#                   Hook          1          1          0          0          0          0
#              Machinary          2          4      0.516       0.25      0.252      0.101
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source=/content/drive/MyDrive/Datasets/construction_safty_OD_v11/test/images
# Out:
# Ultralytics 8.3.54 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11s summary (fused): 238 layers, 9,416,283 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/57 /content/drive/MyDrive/Datasets/construction_safty_OD_v11/test/images/00041_jpg.rf.82ef1882a9e1e286aaee33614785b6e6.jpg: 640x640 1 Hardhat, 2 Safetyvests, 15.7ms
# image 2/57 /content/drive/MyDrive/Datasets/construction_safty_OD_v11/test/images/00087_jpg.rf.613821e97b634dc5c1b8543c29326d94.jpg: 640x640 1 Safetyvest, 15.9ms
# image 3/57 /content/drive/MyDrive/Datasets/construction_safty_OD_v11/test/images/00254_jpg.rf.91db07df8d108a2b0eb3a8395caefb08.jpg: 640x640 3 Safetyvests, 15.6ms
# image 4/57 /content/drive/MyDrive/Datasets/construction_safty_OD_v11/test/images/00629_jpg.rf.f6dda2b9ad688003fbd69bce660e3c00.jpg: 640x640 1 Boots, 1 Person, 15.6ms
# image 5/57 /content/drive/MyDrive/Datasets/construction_safty_OD_v11/test/images/262_jpg.rf.3f1d0fc0e0021423830f2fc4ac3b60cb.jpg: 512x640 1 Person, 44.4ms
# ...
